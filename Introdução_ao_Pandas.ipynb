# %% [markdown]
# <a href="https://colab.research.google.com/github/KepryDeSousa/Python_XPE_Bootcamp/blob/main/Introdu%C3%A7%C3%A3o_ao_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas
#
# * Dados tabulados
#
# * Dados de series temporais ordenados e não
#
# * Dados matriciais arbirtrarios com linhas e colunas

# %% [markdown]
# ### Dataframe e series
#
# *Dataframe é um conjuto de serie
# >  row -> linhas
#  columns -> colunas
#
# * serie é um dict
#
# * comandos basicos :
# > read_csv()
# >
# > read_json()
# >
# >read_excel()
#
#
# *Tratamentos:
# > Tratamento de dados faltantes
# >
# > Grupo de funcoes robustos
# >
# > Ferramentas de IO robustas para leituras de dados de arquivos
# >
# > CSV...

# %%
# para um excel com mais de uma pagina
df = pd.read_excel("planilhatesteNaoExiste",sheet_name= "paginaName")

# %%
df = pd.read_excel("planilhatesteNaoExiste",sheet_name= "paginaName", decimal=",")
#separador sendo ","

# %%
df.head(n_linhas) #print das linhas requeridas

# %%
df.tail(n_linhas) #print das linhas requeridas das ultimas casas

# %%
df.types #tipos dos arquivos

# %%
df.info() #informacoes das colunas

# %%
df.columns # nomes das colunas, se usar o "=" voce pode mudar o nome da coluna

# %% [markdown]
# # Aula_2
# * iloc
# * loc

# %% [markdown]
# * dataframe["temperatura"]# pandas series
#
# * dataframe['coluna 1', 'coluna2'], passando apenas os nomes temos uma especie de slice
#
# * dataframe.iloc[index_Linha,index_colum]
#
# * dataframe.loc[index_coluna] #[sting ou listas dentro]
#
# * dataframe[['classificacao'] == "quente"]
#
# * dataframe.loc[['classificacao'] == "quente"] # apartir das colunas

# %%
#indexação
from google.colab import files
files.upload()

# %%
import pandas as pd
bd = pd.read_excel("Cobertura_Pop_Estimadas.xlsx")

# %%
bd.head(3)
# Out:
#    Municipio UAPS UAPS desativada ESF ESB  ENASFAP  EMSI  EMAD      Pop  \
# 0    Acarape   15               6   6   6      1.0   0.0   0.0  13553.0
# 1  Aracoiaba   17               0  13  13      0.0   0.0   0.0  25522.0
# 2    Aratuba    8               1   6   5      1.0   1.0   0.0  12110.0
#
#    N° Agentes (ACS)
# 0              20.0
# 1              69.0
# 2               0.0

# %%
#selecao 
bd['Municipio'] # excel com elementos limitados ao 13 valor
# Out:
# 0                                               Acarape
# 1                                             Aracoiaba
# 2                                               Aratuba
# 3                                              Barreira
# 4                                              Baturité
# 5                                            Capistrano
# 6                                          Guaramiranga
# 7                                              Itapiúna
# 8                                              Mulungu
# 9                                                 Ocara
# 10                                               Pacoti
# 11                                             Palmácia
# 12                                             Redenção
# 13                                                TOTAL
# 14    Cobertura populacional estimada por Agentes Co...
# 15                                                  NaN
# 16                                                  NaN
# ...

# %%
type(bd.Municipio)
# Out:
# pandas.core.series.Series

# %%
bd = bd.iloc[0:12]
bd
# Out:
#        Municipio UAPS UAPS desativada ESF ESB  ENASFAP  EMSI  EMAD      Pop  \
# 0        Acarape   15               6   6   6      1.0   0.0   0.0  13553.0
# 1      Aracoiaba   17               0  13  13      0.0   0.0   0.0  25522.0
# 2        Aratuba    8               1   6   5      1.0   1.0   0.0  12110.0
# 3       Barreira   15               0   9   7      0.0   0.0   0.0  22412.0
# 4       Baturité   18               4  14  14      0.0   0.0   1.0  33335.0
# 5     Capistrano   10               0   6   6      0.0   0.0   0.0  16005.0
# 6   Guaramiranga    4               0   3   3      1.0   0.0   0.0   5676.0
# 7       Itapiúna   11               3   6   5      1.0   0.0   0.0  17211.0
# 8       Mulungu     5               0   3   3      0.0   0.0   0.0   9851.0
# 9          Ocara   14               1  13  13      0.0   0.0   0.0  24483.0
# 10        Pacoti   17               8   5   5      0.0   0.0   0.0  10467.0
# ...

# %%
bd.iloc[:, 0]
# Out:
# 0          Acarape
# 1        Aracoiaba
# 2          Aratuba
# 3         Barreira
# 4         Baturité
# 5       Capistrano
# 6     Guaramiranga
# 7         Itapiúna
# 8         Mulungu
# 9            Ocara
# 10          Pacoti
# 11        Palmácia
# Name: Municipio, dtype: object

# %%
bd.iloc[:, 1:8]
# Out:
#    UAPS UAPS desativada ESF ESB  ENASFAP  EMSI  EMAD
# 0    15               6   6   6      1.0   0.0   0.0
# 1    17               0  13  13      0.0   0.0   0.0
# 2     8               1   6   5      1.0   1.0   0.0
# 3    15               0   9   7      0.0   0.0   0.0
# 4    18               4  14  14      0.0   0.0   1.0
# 5    10               0   6   6      0.0   0.0   0.0
# 6     4               0   3   3      1.0   0.0   0.0
# 7    11               3   6   5      1.0   0.0   0.0
# 8     5               0   3   3      0.0   0.0   0.0
# 9    14               1  13  13      0.0   0.0   0.0
# 10   17               8   5   5      0.0   0.0   0.0
# 11   13               7   4   3      0.0   0.0   0.0

# %%
bd.loc[:,["Municipio","Pop","N° Agentes (ACS)"]]
# Out:
#        Municipio      Pop  N° Agentes (ACS)
# 0        Acarape  13553.0              20.0
# 1      Aracoiaba  25522.0              69.0
# 2        Aratuba  12110.0               0.0
# 3       Barreira  22412.0              38.0
# 4       Baturité  33335.0              87.0
# 5     Capistrano  16005.0              35.0
# 6   Guaramiranga   5676.0              15.0
# 7       Itapiúna  17211.0              50.0
# 8       Mulungu    9851.0              21.0
# 9          Ocara  24483.0              63.0
# 10        Pacoti  10467.0              14.0
# 11      Palmácia  10173.0              22.0

# %% [markdown]
# # Aula_3
# * Indexação Booleana

# %%
bd.dtypes
# Out:
# Municipio            object
# UAPS                 object
# UAPS desativada      object
# ESF                  object
# ESB                  object
# ENASFAP             float64
# EMSI                float64
# EMAD                float64
# Pop                 float64
# N° Agentes (ACS)    float64
# dtype: object

# %%
# transformar object em dataframes

bd.UAPS = pd.to_datetime(bd['UAPS']) # houve uma conversão ´para tempo dos dados
#pesquisar demais metodos para transformar similares "pd.to_"

# %%
bd.dtypes
# Out:
# Municipio                   object
# UAPS                datetime64[ns]
# UAPS desativada             object
# ESF                         object
# ESB                         object
# ENASFAP                    float64
# EMSI                       float64
# EMAD                       float64
# Pop                        float64
# N° Agentes (ACS)           float64
# dtype: object

# %%
#dica deixar a coluna de data como index 0 para viabilizar futuros graficos
#como n tenho coluna de tempo apenas setar alguma

a = bd.set_index("Municipio")

# %%
bd
# Out:
#        Municipio                          UAPS UAPS desativada ESF ESB  \
# 0        Acarape 1970-01-01 00:00:00.000000015               6   6   6
# 1      Aracoiaba 1970-01-01 00:00:00.000000017               0  13  13
# 2        Aratuba 1970-01-01 00:00:00.000000008               1   6   5
# 3       Barreira 1970-01-01 00:00:00.000000015               0   9   7
# 4       Baturité 1970-01-01 00:00:00.000000018               4  14  14
# 5     Capistrano 1970-01-01 00:00:00.000000010               0   6   6
# 6   Guaramiranga 1970-01-01 00:00:00.000000004               0   3   3
# 7       Itapiúna 1970-01-01 00:00:00.000000011               3   6   5
# 8       Mulungu  1970-01-01 00:00:00.000000005               0   3   3
# 9          Ocara 1970-01-01 00:00:00.000000014               1  13  13
# 10        Pacoti 1970-01-01 00:00:00.000000017               8   5   5
# 11      Palmácia 1970-01-01 00:00:00.000000013               7   4   3
#
# ...

# %%
Pop = bd["Pop"] >= 22000
bd.loc[Pop,"Municipio"]
# Out:
# 1    Aracoiaba
# 3     Barreira
# 4     Baturité
# 9        Ocara
# Name: Municipio, dtype: object

# %% [markdown]
# # Aula_4
#
# *Comandos de Organização

# %%
bd.sort_values(by="Municipio")
# organização por colunas, apartir do "by="
# Out:
#        Municipio                          UAPS UAPS desativada ESF ESB  \
# 0        Acarape 1970-01-01 00:00:00.000000015               6   6   6
# 1      Aracoiaba 1970-01-01 00:00:00.000000017               0  13  13
# 2        Aratuba 1970-01-01 00:00:00.000000008               1   6   5
# 3       Barreira 1970-01-01 00:00:00.000000015               0   9   7
# 4       Baturité 1970-01-01 00:00:00.000000018               4  14  14
# 5     Capistrano 1970-01-01 00:00:00.000000010               0   6   6
# 6   Guaramiranga 1970-01-01 00:00:00.000000004               0   3   3
# 7       Itapiúna 1970-01-01 00:00:00.000000011               3   6   5
# 8       Mulungu  1970-01-01 00:00:00.000000005               0   3   3
# 9          Ocara 1970-01-01 00:00:00.000000014               1  13  13
# 10        Pacoti 1970-01-01 00:00:00.000000017               8   5   5
# 11      Palmácia 1970-01-01 00:00:00.000000013               7   4   3
#
# ...

# %%
bd.sort_values(by=["UAPS desativada","ESF"],ascending=False) #com listas
# Out:
#        Municipio                          UAPS UAPS desativada ESF ESB  \
# 10        Pacoti 1970-01-01 00:00:00.000000017               8   5   5
# 11      Palmácia 1970-01-01 00:00:00.000000013               7   4   3
# 0        Acarape 1970-01-01 00:00:00.000000015               6   6   6
# 4       Baturité 1970-01-01 00:00:00.000000018               4  14  14
# 7       Itapiúna 1970-01-01 00:00:00.000000011               3   6   5
# 9          Ocara 1970-01-01 00:00:00.000000014               1  13  13
# 2        Aratuba 1970-01-01 00:00:00.000000008               1   6   5
# 1      Aracoiaba 1970-01-01 00:00:00.000000017               0  13  13
# 3       Barreira 1970-01-01 00:00:00.000000015               0   9   7
# 5     Capistrano 1970-01-01 00:00:00.000000010               0   6   6
# 6   Guaramiranga 1970-01-01 00:00:00.000000004               0   3   3
# 8       Mulungu  1970-01-01 00:00:00.000000005               0   3   3
#
# ...

# %%
# Sort_values vs sort_index
bd.sort_index()
# Out:
#        Municipio                          UAPS UAPS desativada ESF ESB  \
# 0        Acarape 1970-01-01 00:00:00.000000015               6   6   6
# 1      Aracoiaba 1970-01-01 00:00:00.000000017               0  13  13
# 2        Aratuba 1970-01-01 00:00:00.000000008               1   6   5
# 3       Barreira 1970-01-01 00:00:00.000000015               0   9   7
# 4       Baturité 1970-01-01 00:00:00.000000018               4  14  14
# 5     Capistrano 1970-01-01 00:00:00.000000010               0   6   6
# 6   Guaramiranga 1970-01-01 00:00:00.000000004               0   3   3
# 7       Itapiúna 1970-01-01 00:00:00.000000011               3   6   5
# 8       Mulungu  1970-01-01 00:00:00.000000005               0   3   3
# 9          Ocara 1970-01-01 00:00:00.000000014               1  13  13
# 10        Pacoti 1970-01-01 00:00:00.000000017               8   5   5
# 11      Palmácia 1970-01-01 00:00:00.000000013               7   4   3
#
# ...

# %% [markdown]
# # Aula_5

# %%
bd.plot()#plot linhas, ele vai executar apartir do index
# Out:
# <Axes: >

# %%
bd.plot(figsize=(14,5),grid=True,style="-o",color="red") #tamanho H, T vertical
# Out:
# <Axes: >

# %% [markdown]
# # Aula_6

# %%
bd.groupby(by="Pop")

# %%
bd.groupby(by="Pop")
bd
# Out:
#        Municipio                          UAPS UAPS desativada ESF ESB  \
# 0        Acarape 1970-01-01 00:00:00.000000015               6   6   6
# 1      Aracoiaba 1970-01-01 00:00:00.000000017               0  13  13
# 2        Aratuba 1970-01-01 00:00:00.000000008               1   6   5
# 3       Barreira 1970-01-01 00:00:00.000000015               0   9   7
# 4       Baturité 1970-01-01 00:00:00.000000018               4  14  14
# 5     Capistrano 1970-01-01 00:00:00.000000010               0   6   6
# 6   Guaramiranga 1970-01-01 00:00:00.000000004               0   3   3
# 7       Itapiúna 1970-01-01 00:00:00.000000011               3   6   5
# 8       Mulungu  1970-01-01 00:00:00.000000005               0   3   3
# 9          Ocara 1970-01-01 00:00:00.000000014               1  13  13
# 10        Pacoti 1970-01-01 00:00:00.000000017               8   5   5
# 11      Palmácia 1970-01-01 00:00:00.000000013               7   4   3
#
# ...

# %%
#remover linha do df

drop = bd
drop.drop("Pop", axis=1)
# Out:
#        Municipio                          UAPS UAPS desativada ESF ESB  \
# 0        Acarape 1970-01-01 00:00:00.000000015               6   6   6
# 1      Aracoiaba 1970-01-01 00:00:00.000000017               0  13  13
# 2        Aratuba 1970-01-01 00:00:00.000000008               1   6   5
# 3       Barreira 1970-01-01 00:00:00.000000015               0   9   7
# 4       Baturité 1970-01-01 00:00:00.000000018               4  14  14
# 5     Capistrano 1970-01-01 00:00:00.000000010               0   6   6
# 6   Guaramiranga 1970-01-01 00:00:00.000000004               0   3   3
# 7       Itapiúna 1970-01-01 00:00:00.000000011               3   6   5
# 8       Mulungu  1970-01-01 00:00:00.000000005               0   3   3
# 9          Ocara 1970-01-01 00:00:00.000000014               1  13  13
# 10        Pacoti 1970-01-01 00:00:00.000000017               8   5   5
# 11      Palmácia 1970-01-01 00:00:00.000000013               7   4   3
#
#     ENASFAP  EMSI  EMAD  N° Agentes (ACS)
# ...

# %%
bd
# Out:
#        Municipio                          UAPS UAPS desativada ESF ESB  \
# 0        Acarape 1970-01-01 00:00:00.000000015               6   6   6
# 1      Aracoiaba 1970-01-01 00:00:00.000000017               0  13  13
# 2        Aratuba 1970-01-01 00:00:00.000000008               1   6   5
# 3       Barreira 1970-01-01 00:00:00.000000015               0   9   7
# 4       Baturité 1970-01-01 00:00:00.000000018               4  14  14
# 5     Capistrano 1970-01-01 00:00:00.000000010               0   6   6
# 6   Guaramiranga 1970-01-01 00:00:00.000000004               0   3   3
# 7       Itapiúna 1970-01-01 00:00:00.000000011               3   6   5
# 8       Mulungu  1970-01-01 00:00:00.000000005               0   3   3
# 9          Ocara 1970-01-01 00:00:00.000000014               1  13  13
# 10        Pacoti 1970-01-01 00:00:00.000000017               8   5   5
# 11      Palmácia 1970-01-01 00:00:00.000000013               7   4   3
#
# ...
